# %% [markdown]
# Бредня Елизавета, ИУ5-64
#
# Вариант 2 - задача 1 - набор данных 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Загружаем датасет

# %%
from sklearn.datasets import load_iris
data = load_iris(as_frame=True).frame
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# Пропуски отсутствуют:

# %%
data.isna().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %%
data.corr()
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
# target                      0.782561         -0.426658           0.949035
#
#                    petal width (cm)    target
# sepal length (cm)          0.817941  0.782561
# sepal width (cm)          -0.366126 -0.426658
# petal length (cm)          0.962865  0.949035
# petal width (cm)           1.000000  0.956547
# target                     0.956547  1.000000

# %% [markdown]
# Можно проверить корреляцию по коэффициентам корреляции Кендалла и Спирмена:

# %%
data.corr(method='kendall')
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.076997           0.718516
# sepal width (cm)           -0.076997          1.000000          -0.185994
# petal length (cm)           0.718516         -0.185994           1.000000
# petal width (cm)            0.655309         -0.157126           0.806891
# target                      0.670444         -0.337614           0.822911
#
#                    petal width (cm)    target
# sepal length (cm)          0.655309  0.670444
# sepal width (cm)          -0.157126 -0.337614
# petal length (cm)          0.806891  0.822911
# petal width (cm)           1.000000  0.839687
# target                     0.839687  1.000000

# %%
data.corr(method='kendall')
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.076997           0.718516
# sepal width (cm)           -0.076997          1.000000          -0.185994
# petal length (cm)           0.718516         -0.185994           1.000000
# petal width (cm)            0.655309         -0.157126           0.806891
# target                      0.670444         -0.337614           0.822911
#
#                    petal width (cm)    target
# sepal length (cm)          0.655309  0.670444
# sepal width (cm)          -0.157126 -0.337614
# petal length (cm)          0.806891  0.822911
# petal width (cm)           1.000000  0.839687
# target                     0.839687  1.000000

# %% [markdown]
# Для наглядности построим хитмап:

# %%
sns.heatmap(data.corr(), annot=True, fmt='.3f', cmap='magma')

# %% [markdown]
# Можем увидеть, что сильнее всего на результат влияют petal length и petal width. Но для модели машинного обучения нужно будет взять все столбцы, потому что совсем неважных нет.

# %% [markdown]
# Violin plot для petal width:

# %%
sns.violinplot(x=data['petal length (cm)'])
